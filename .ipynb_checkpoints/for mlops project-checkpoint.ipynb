# %%
from keras.datasets import mnist
# Out:
# Using TensorFlow backend.

# %%
dataset = mnist.load_data("mymnist.data")

# %%
len(dataset)
# Out:
# 2

# %%
train, test = dataset

# %%
len(train)
# Out:
# 2

# %%
len(test)
# Out:
# 2

# %% [markdown]
# ### Length of train and test are returning 2 because they are further divided into train_X , train_y and test_X , test_y

# %%
train_X , train_y = train
test_X , test_y = test

# %%
train_X.shape
# Out:
# (60000, 28, 28)

# %%
test_X.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# ### They have taken 60000 observations for training and 10000 for testing

# %%
import matplotlib.pyplot as plt

# %%
img = train_X[9]
img2 = train_X[5]
img3 = train_X[2020]

# %%
plt.imshow(img)

# %%
train_y[9]
# Out:
# 4

# %%
plt.imshow(img2)

# %%
train_y[5]
# Out:
# 2

# %%
plt.imshow(img3)

# %%
train_y[2020]
# Out:
# 6

# %%
img.shape
# Out:
# (28, 28)

# %% [markdown]
# ### Image is in 2D but we need any data in only vector format for traing model.

# %%
rimg = img.reshape(28*28)
rimg.shape
# Out:
# (784,)

# %%
test_X = test_X.reshape(-1 , 28*28)
train_X = train_X.reshape(-1 ,  28*28)

# %%
train_X.shape
# Out:
# (60000, 784)

# %%
test_X = test_X.astype("float32")
train_X = train_X.astype("float32")

# %% [raw]
# It is always better to have all the features in float rather than in int

# %%
from keras.utils.np_utils import to_categorical

# %%
test_y = to_categorical(test_y)
train_y = to_categorical(train_y)

# %% [markdown]
# ### we have converted our y into categorical variable as their are categories from 0 to 9

# %%
from keras.models import Sequential

# %%
model = Sequential()

# %% [raw]
# Empty model of type sequential has been created

# %%
from keras.layers import Dense

# %%
model.add(Dense(units=600 , input_dim = 28*28 , activation = 'relu'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 600)               471000
# =================================================================
# Total params: 471,000
# Trainable params: 471,000
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Here we have created initial layer.

# %%
model.add(Dense(units=200 , input_dim = 28*28 , activation = 'relu'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 600)               471000
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               120200
# =================================================================
# Total params: 591,200
# Trainable params: 591,200
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(Dense(units=60 , input_dim = 28*28 , activation = 'relu'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 600)               471000
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               120200
# _________________________________________________________________
# dense_3 (Dense)              (None, 60)                12060
# =================================================================
# Total params: 603,260
# Trainable params: 603,260
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Now I have added 3 hidden layers so next is Output layer

# %%
model.add(Dense(units=10 , input_dim = 28*28 , activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 600)               471000
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               120200
# _________________________________________________________________
# dense_3 (Dense)              (None, 60)                12060
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                610
# =================================================================
# Total params: 603,870
# Trainable params: 603,870
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import Adam

# %%
model.compile( optimizer= "Adam" , loss='categorical_crossentropy', 
             metrics=['accuracy'] )

# %%
fit_model = model.fit(train_X ,  train_y , epochs = 30)
# Out:
# Epoch 1/30
# 60000/60000 [==============================] - 34s 562us/step - loss: 0.9971 - accuracy: 0.8677
# Epoch 2/30
# 60000/60000 [==============================] - 34s 574us/step - loss: 0.2208 - accuracy: 0.9429
# Epoch 3/30
# 60000/60000 [==============================] - 34s 569us/step - loss: 0.1708 - accuracy: 0.9556
# Epoch 4/30
# 60000/60000 [==============================] - 35s 588us/step - loss: 0.1250 - accuracy: 0.9660
# Epoch 5/30
# 60000/60000 [==============================] - 35s 579us/step - loss: 0.1134 - accuracy: 0.9708
# Epoch 6/30
# 60000/60000 [==============================] - 36s 598us/step - loss: 0.0929 - accuracy: 0.9748
# Epoch 7/30
# 60000/60000 [==============================] - 35s 591us/step - loss: 0.0816 - accuracy: 0.9785s - loss: 0.0811 - ac
# Epoch 8/30
# 60000/60000 [==============================] - 35s 587us/step - loss: 0.0753 - accuracy: 0.9810s - loss: 0.075
# Epoch 9/30
# 60000/60000 [==============================] - 35s 588us/step - loss: 0.0703 - accuracy: 0.9829
# Epoch 10/30
# 60000/60000 [==============================] - 35s 591us/step - loss: 0.0638 - accuracy: 0.9844
# Epoch 11/30
# 60000/60000 [==============================] - 35s 587us/step - loss: 0.0563 - accuracy: 0.9866
# Epoch 12/30
# 60000/60000 [==============================] - 36s 599us/step - loss: 0.0556 - accuracy: 0.9871
# Epoch 13/30
# 60000/60000 [==============================] - 35s 590us/step - loss: 0.0607 - accuracy: 0.9872
# Epoch 14/30
# 60000/60000 [==============================] - 37s 621us/step - loss: 0.0590 - accuracy: 0.9866s - loss: 0.0589 - ac - ETA: 0s - loss: 0.0589
# Epoch 15/30
# 60000/60000 [==============================] - 36s 604us/step - loss: 0.0488 - accuracy: 0.9888
# Epoch 16/30
# 60000/60000 [==============================] - 36s 604us/step - loss: 0.0536 - accuracy: 0.9888
# Epoch 17/30
# 60000/60000 [==============================] - 36s 599us/step - loss: 0.0510 - accuracy: 0.9898
# Epoch 18/30
# 60000/60000 [==============================] - 36s 593us/step - loss: 0.0438 - accuracy: 0.9910s - loss: 0.0
# Epoch 19/30
# 60000/60000 [==============================] - 39s 642us/step - loss: 0.0389 - accuracy: 0.9915s - loss: 0.0391 - accuracy
# Epoch 20/30
# 60000/60000 [==============================] - 38s 627us/step - loss: 0.0522 - accuracy: 0.9898
# Epoch 21/30
# 60000/60000 [==============================] - 37s 614us/step - loss: 0.0478 - accuracy: 0.9902
# Epoch 22/30
# 60000/60000 [==============================] - 37s 617us/step - loss: 0.0437 - accuracy: 0.9917
# Epoch 23/30
# 60000/60000 [==============================] - 36s 607us/step - loss: 0.0489 - accuracy: 0.9905
# Epoch 24/30
# 60000/60000 [==============================] - 39s 654us/step - loss: 0.0416 - accuracy: 0.9923
# Epoch 25/30
# 60000/60000 [==============================] - 36s 602us/step - loss: 0.0505 - accuracy: 0.9909
# Epoch 26/30
# 60000/60000 [==============================] - 36s 595us/step - loss: 0.0626 - accuracy: 0.9903
# Epoch 27/30
# 60000/60000 [==============================] - 36s 604us/step - loss: 0.0495 - accuracy: 0.9906
# Epoch 28/30
# 60000/60000 [==============================] - 36s 593us/step - loss: 0.0370 - accuracy: 0.9930
# Epoch 29/30
# 60000/60000 [==============================] - 37s 616us/step - loss: 0.0426 - accuracy: 0.9915
# Epoch 30/30
# 60000/60000 [==============================] - 36s 600us/step - loss: 0.0638 - accuracy: 0.9893

# %% [markdown]
# ### Model trained by 98.93% Accuracy

# %%
model.save("number detection model.pk1")

# %%
immg = test_X[4].transpose()

# %%
import numpy

# %%
if (test_X[7].ndim == 1):
    XpredictInputData = numpy.array([test_X[7]])

# %%
imgg = model.predict(XpredictInputData)

# %%
plt.imshow(imgg)

# %%
plt.imshow([test_y[7]])

# %%
if (test_X[18].ndim == 1):
    XpredictInputData = numpy.array([test_X[18]])

# %%
imgg = model.predict(XpredictInputData)

# %%
plt.imshow(imgg)

# %%
plt.imshow([test_y[18]])
